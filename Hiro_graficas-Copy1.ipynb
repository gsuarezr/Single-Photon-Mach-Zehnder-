# %% [markdown]
# # First we import the necessary lbraries, This part is just so I can illustrate how this program works, It is way better explained in the Symbolic version of this [1](my link on github)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # In this cell we simply define how many interferometers we want(It's actually how many BS as explained on the thesis), the ones below just run the previouly explained algorithm numerically to generate graphs a functon that gives the arrays plotted is given at the end of ths notebook

# %%
N=200
alpha =np.pi/(2*N)

# %%
B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
B.shape
# Out:
# (2, 2)

# %%
n=1
A=np.matrix([[ np.sqrt(n),0],[0,1]])
A.shape
#A=Matrix([[ cos(n),0],[0,1]])
#A=Matrix([[(n*(1-sign(sin(t)))/2)+(1+sign(sin(t)))/2,0],[0,1]])
#A.subs(t,3*pi/2)
# Out:
# (2, 2)

# %%
jones1= np.matrix([[0],[1]])
jones0= np.matrix([[1],[0]])

# %%
prob=np.zeros(0)
prob_2=np.zeros(0)
n=1
A=np.matrix([[ np.sqrt(n),0],[0,1]])
for i in range(1,200):
    alpha =np.pi/(2*i)
    B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
    Paola=(B*A)**(i-1)
    prob=np.append(prob,(jones1.T)*Paola*B*jones1)
    prob_2=np.append(prob_2,(jones0.T)*Paola*B*jones1)
prob_abs=1-(np.absolute(np.square(prob))+np.absolute(np.square(prob_2)))

# %%
prob1=np.zeros(0)
prob1_2=np.zeros(0)
n=0.5
A=np.matrix([[ np.sqrt(n),0],[0,1]])
for i in range(1,200):
    alpha =np.pi/(2*i)
    B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
    Paola=(B*A)**(i-1)
    prob1=np.append(prob1,(jones1.T)*Paola*B*jones1)
    prob1_2=np.append(prob1_2,(jones0.T)*Paola*B*jones1)
prob1_abs=1-(np.absolute(np.square(prob1))+np.absolute(np.square(prob1_2)))

# %%
prob2=np.zeros(0)
prob2_2=np.zeros(0)
n=0.2
A=np.matrix([[ np.sqrt(n),0],[0,1]])
for i in range(1,200):
    alpha =np.pi/(2*i)
    B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
    Paola=(B*A)**(i-1)
    prob2=np.append(prob2,(jones1.T)*Paola*B*jones1)
    prob2_2=np.append(prob2_2,(jones0.T)*Paola*B*jones1)
prob2_abs=1-(np.absolute(np.square(prob2))+np.absolute(np.square(prob2_2)))

# %%
prob3=np.zeros(0)
prob3_2=np.zeros(0)
n=0.015
A=np.matrix([[ np.sqrt(n),0],[0,1]])
for i in range(1,200):
    alpha =np.pi/(2*i)
    B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
    Paola=(B*A)**(i-1)
    prob3=np.append(prob3,(jones1.T)*Paola*B*jones1)
    prob3_2=np.append(prob3_2,(jones0.T)*Paola*B*jones1)
prob3_abs=1-(np.absolute(np.square(prob3))+np.absolute(np.square(prob3_2)))

# %%
prob4=np.zeros(0)
prob4_2=np.zeros(0)
n=0.002
A=np.matrix([[ np.sqrt(n),0],[0,1]])
for i in range(1,200):
    alpha =np.pi/(2*i)
    B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
    Paola=(B*A)**(i-1)
    prob4=np.append(prob4,(jones1.T)*Paola*B*jones1)
    prob4_2=np.append(prob4_2,(jones0.T)*Paola*B*jones1)
prob4_abs=1-(np.absolute(np.square(prob4))+np.absolute(np.square(prob4_2)))

# %%
prob5=np.zeros(0)
prob5_2=np.zeros(0)
n=0.8
A=np.matrix([[ np.sqrt(n),0],[0,1]])
for i in range(1,200):
    alpha =np.pi/(2*i)
    B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
    Paola=(B*A)**(i-1)
    prob5=np.append(prob5,(jones1.T)*Paola*B*jones1)
    prob5_2=np.append(prob5_2,(jones0.T)*Paola*B*jones1)
prob5_abs=1-(np.absolute(np.square(prob5))+np.absolute(np.square(prob5_2)))

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
N=np.linspace(1,199,199)
plt.plot(N,np.square(np.absolute(prob_2)),label=r'n=$1$')
plt.plot(N,np.square(np.absolute(prob1_2)),label=r'n=$0.5$')
plt.plot(N,np.square(np.absolute(prob2_2)),label=r'n=$0.2$')
plt.plot(N,np.square(np.absolute(prob3_2)),label=r'n=$0.015$')
plt.plot(N,np.square(np.absolute(prob4_2)),label=r'n=$0.002$')
plt.plot(N,np.square(np.absolute(prob5_2)),label=r'n=$0.8$')


plt.xlabel(r'Numero de Beam Splitters')
plt.ylabel(r'Probabilidad en D2')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N=np.linspace(1,199,199)
plt.plot(N,np.square(np.absolute(prob)),label=r'n=$1$')
plt.plot(N,np.square(np.absolute(prob1)),label=r'n=$0.5$')
plt.plot(N,np.square(np.absolute(prob2)),label=r'n=$0.2$')
plt.plot(N,np.square(np.absolute(prob3)),label=r'n=$0.015$')
plt.plot(N,np.square(np.absolute(prob4)),label=r'n=$0.002$')
plt.plot(N,np.square(np.absolute(prob5)),label=r'n=$0.8$')


plt.xlabel(r'$N$')
plt.ylabel(r'$ PD_{1} $')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N=np.linspace(1,199,199)
plt.plot(N,prob_abs,label=r'n=1')
plt.plot(N,prob1_abs,label=r'n=0.5')
plt.plot(N,prob2_abs,label=r'n=0.2')
plt.plot(N,prob3_abs,label=r'n=0.015')
plt.plot(N,prob4_abs,label=r'n=0.002')
plt.plot(N,prob5_abs,label=r'n=0.8')


plt.xlabel('Numero de Beam Splitters')
plt.ylabel('Probabilidad de ser Absorbido')
plt.xlim(1,50)
plt.ylim(0,1.2)
plt.xticks(np.arange(1,202,25))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def Azuma(N,n):
    prob=np.zeros(0)
    prob_2=np.zeros(0)
    A=np.matrix([[ np.sqrt(n),0],[0,1]])
    jones1= np.matrix([[0],[1]])
    jones0= np.matrix([[1],[0]])
    for i in range(1,N+1):
        alpha =np.pi/(2*i)
        B=np.matrix([[np.cos(alpha),1j*np.sin(alpha)],[1j*np.sin(alpha),np.cos(alpha)]])
        Paola=(B*A)**(i-1)
        prob=np.append(prob,(jones1.T)*Paola*B*jones1)
        prob_2=np.append(prob_2,(jones0.T)*Paola*B*jones1)
        prob_abs=1-(np.absolute(np.square(prob))+np.absolute(np.square(prob_2)))  
    return prob,prob_2,prob_abs

# %% [markdown]
# # Previously we just repeated to generate the plots of several cases, the function below does a graph for any case wanted for each of the three posible outcomes

# %%
def plot_azuma(N,n):
    pd1,pd2,pabs=Azuma(N,n)
    N=np.linspace(1,N,N)
    plt.plot(N,np.square(np.absolute(pd1)),label=r'$PD_{1}$')
    plt.plot(N,np.square(np.absolute(pd2)),label=r'$PD_{2}$')
    plt.plot(N,pabs,label=r'$P_{abs}$')

    plt.xlabel(r'$N$')
    plt.ylabel(r'$ P(N)$')
    plt.xlim(1,50)
    plt.ylim(0,1.05)
    plt.legend()
    return plt.show()

# %%
plot_azuma(50,0.6)
# Out:
# <img src="data:image/png;base64,..." width="640">
