# %% [markdown]
# # In this notebook we simply realize the plots for the spatial correlations in the SPDC process, more information on how to make the expressions for the integration can be found in [1](https://onlinelibrary.wiley.com/doi/abs/10.1002/mma.3192) in the cells below we simply define the necessary libraries for symbolic calculus in sympy and write the expresssions to Integrate

# %%
from sympy import *
init_printing()
import numpy as np

# %%
qxs,qys,qxi,qyi,xs,ys,xi,yi,sigma,sigmax,sigmay=symbols('qxs qys qxi qyi xs ys xi yi sigma sigmax sigmay',real=True)

# %%
def phi(qxs,qys,qxi,qyi,xi,yi,xs,ys,sigma,sigmax,sigmay):
    alpha=exp(-sigma**2 * ((qxi+qxs)**2 +(qyi+qys)**2))
    beta= exp(-((sigmax*qxi)**2 +(sigmay*qyi)**2))
    kappa=exp(-((sigmax*qxs)**2 +(sigmay*qys)**2))
    theta=(exp(-I*qxi*xi) )*(exp(-I*qyi*yi))
    etta=(exp(-I*qxs*xs))*(exp(-I*qys*ys))
    return alpha*beta*kappa*etta*theta

# %%
phi(qxs,qys,qxi,qyi,xi,yi,xs,ys,sigma,sigmax,sigmay)
# Out:
#    2 ⎛           2              2⎞
#  -σ ⋅⎝(qxi + qxs)  + (qyi + qys) ⎠  -ⅈ⋅qxi⋅ξ  -ⅈ⋅qxs⋅xs  -ⅈ⋅qyi⋅yi  -ⅈ⋅qys⋅ys
# ℯ                                 ⋅ℯ        ⋅ℯ         ⋅ℯ         ⋅ℯ         ⋅
#
#       2       2      2       2       2       2      2       2
#  - qxi ⋅sigmax  - qyi ⋅sigmay   - qxs ⋅sigmax  - qys ⋅sigmay
# ℯ                             ⋅ℯ

# %% [markdown]
# # Now we integrate with sympy, both mathematica and sympy cannot handle arbitratry $\sigma,\sigma_{x},\sigma_{y}$ so we fix those values in the function

# %%
a=integrate(phi(qxs,qys,qxi,qyi,xi,yi,xs,ys,0.18,0.59,0.1),(qys,-oo,oo))

# %%
a=a.simplify()

# %%
b=integrate(a,(qxs,-oo,oo))

# %%
b=b.simplify()

# %%
c=integrate(b,(qxi,-oo,oo))

# %%
c=c.simplify()

# %%
d=integrate(c,(qyi,-oo,oo))

# %%
d=d.simplify()

# %% [markdown]
# # This is the analytical answer for those values of $\sigma,\sigma_{x},\sigma_{y}$

# %%
d
# Out:
#
#  2
# π ⋅((erf(ⅈ⋅(3.76445520555796⋅yi - 2.87661199669995⋅ys)) + 1)⋅(24.1109741073011
#
#
#
# ⋅erf(ⅈ⋅(0.813528705708387⋅ξ - 0.0692728779630795⋅xs)) + 24.1109741073011⋅erfc(
#
#
#
# ⅈ⋅(0.813528705708387⋅ξ - 0.0692728779630795⋅xs)) + 24.1109741073011) + (24.110
#
#
#
# 9741073011⋅erf(ⅈ⋅(0.813528705708387⋅ξ - 0.0692728779630795⋅xs)) + 24.110974107
#
#
#
# 3011⋅erfc(ⅈ⋅(0.813528705708387⋅ξ - 0.0692728779630795⋅xs)) + 24.1109741073011)
#
#                                                                             2
#                                                        - 0.661828955011564⋅ξ
# ⋅erfc(ⅈ⋅(3.76445520555796⋅yi - 2.87661199669995⋅ys)))⋅ℯ
#
#                                                2                      2
# + 0.112710949499998⋅ξ⋅xs - 0.661828955011564⋅xs  - 5.89622641509434⋅ys  - 14.1
#
#
#                                             2
# 711229946524⋅(1.0⋅yi - 0.764150943396226⋅ys)

# %% [markdown]
# # Then we simply import libraries to plot and get the spatial correlation plots

# %%
from sympy.plotting import plot3d
import matplotlib.pyplot as plt
import matplotlib.colorbar
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %% [markdown]
# # The next function makes plots with colorbars, only problem is that it makes duplicates of the plot, I'm trying to fix it

# %%
def con_barra(plot):
    plot2 = plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    backend = plot2.backend(plot2)
    backend.ax = ax
    backend._process_series(backend.parent._series, ax, backend.parent)
    plt.close(backend.fig)
    ax.collections[0].set_cmap('viridis') # optionally change the colormap
    plt.colorbar(ax.collections[0])
    return plt.show()

# %% [markdown]
# # This one is the $x_{i}, x_{s}$ correlation, Note that the number of points in the graphs are quite low that is because it takes a little while to create graphs whi more points ,it can be changed by changing the number in  nb_of_points_x and nb_of_points_y

# %%
primera=d.subs(ys,0).subs(yi,0)
primera=primera/primera.subs(xs,0).subs(xi,0)
con_barra(plot3d(primera,(xi,-pi,pi),(xs,-pi,pi),xlabel=r'$x_{i}(mm)$',
                 ylabel=r'$x_{s}$(mm)',title=r'$\phi$',nb_of_points_x=50,nb_of_points_y=50))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
#  # This one is the $y_{i}, y_{s}$ correlation

# %%
segunda=d.subs(xs,0).subs(xi,0)
segunda=segunda/segunda.subs(ys,0).subs(yi,0)
con_barra(plot3d(segunda,(yi,-pi,pi),(ys,-pi,pi),xlabel=r'$y_{i}(mm)$',ylabel=r'$y_{s}$(mm)'
                 ,title=r'$\phi$',nb_of_points_x=90,nb_of_points_y=90))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
ter=d.subs(ys,0).subs(xi,0)
ter=ter/ter.subs(xs,0).subs(yi,0)
con_barra(plot3d(ter,(yi,-pi,pi),(xs,-pi,pi),xlabel=r'$y_{i}(mm)$',ylabel=r'$x_{s}$(mm)',title=r'$\phi$',nb_of_points_x=50,nb_of_points_y=50))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
ter=d.subs(xs,0).subs(yi,0)
ter=ter/ter.subs(xi,0).subs(ys,0)
con_barra(plot3d(ter,(xi,-pi,pi),(ys,-pi,pi),xlabel=r'$x_{i}(mm)$',ylabel=r'$y_{s}$(mm)',title=r'$\phi$',nb_of_points_x=50,nb_of_points_y=50))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
